# %%
from Maze import Maze
import tkinter as tk

class MazeSimmulator:

    def __init__(self,width,height):
        self._width = width
        self._height = height
        self._maze = Maze.Maze(self._width,self._height)
        self._maze.create()
        self._maze.dig(1,1)
        
        startPoint = [1,1]
        goalPoint = self._maze.getRandomEndPath()

        
        self._maze.setStartPoint(startPoint[0],startPoint[1])
        self._maze.setGoalPoint(goalPoint[0],goalPoint[1])
    
    def draw(self):
        self._maze.draw89
        
    def playAuto(self):
        self._maze.setPlayer(self._startPoint[0],self._startPoint[1])
        self._maze.playAuto01()
    
    def playAstar(self):
        
        self._maze.setPlayer(self._startPoint[0],self._startPoint[1])
        
        checkPointList=[]
        while True:
            direciton = -1
            derctions = []
            
            if self.isMovablePoint(Maze.Maze.UP)==True:
                directions.append(Maze.Maze.UP)
            elif self.isMovablePoint(Maze.Maze.DOWN)==True:
                directions.append(Maze.Maze.DOWN)
            elif self.isMovablePoint(Maze.Maze.LEFT)==True:
                directions.append(Maze.Maze.LEFT)
            elif self.isMovablePoint(Maze.Maze.RIGHT)==True:
                directions.append(Maze.Maze.RIGHT)
                
            if len(directions)==0:
                break
                
            for d in directions:
                targetPoint = []
                if d == Maze.Maze.UP:
                    targetPoint = [playerPointX,playerPointY-1]
                elif d == Maze.Maze.DOWN:
                    targetPoint ==[playerPointX,playerPointY+1]
                elif d == Maze.Maze.LEFT:
                    targetPoint ==[playerPointX-1,playerPointY]
                elif d == Maze.Maze.RIGHT:
                    targetPoint ==[playerPointX+1,playerPointY]
                
                for c in checkPoints:
                    cheakX=c[0]
                    cheakX=c[1]
                    
                    if cheakX ==targetPoint[0] and checkY == targetPoint[1]:
                        isContain = True
                        break
                        
                    
    

    def isMovablePoint(self.direction):
        mazeData=self._maze._data
        playerPoint = self._maze
